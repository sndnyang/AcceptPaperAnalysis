# %% [markdown]
# # Import library

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import nltk
import json

# %% [markdown]
# # Accept Rate

# %%
import pyecharts.options as opts
from pyecharts.charts import Bar, Line
x_data = ["2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"]
total_submission = [1105, 1219, 1400, 1467, 1420, 1678, 1838, 2403, 3240, 4856, 6743]
accept = [263, 293, 308, 366, 359, 441, 403, 569, 678, 1011, 1429]
rate = list(np.floor(1000 * np.array(accept) / np.array(total_submission)) / 10)

bar = (
    Bar(init_opts=opts.InitOpts(width="1000px", height="500px"))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="Submission",
        yaxis_data=total_submission,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="Accepted",
        yaxis_data=accept,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="Accept Rate",
            type_="value",
            min_=0,
            max_=100,
            interval=20,
            axislabel_opts=opts.LabelOpts(formatter="{value}%"),
        )
    )
    .set_global_opts(
        tooltip_opts=opts.TooltipOpts(
            is_show=True, trigger="axis", axis_pointer_type="cross"
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            axispointer_opts=opts.AxisPointerOpts(is_show=True, type_="shadow"),
        ),
        yaxis_opts=opts.AxisOpts(
            name="Submission Number",
            type_="value",
            min_=0,
            max_=7000,
            interval=1000,
            axislabel_opts=opts.LabelOpts(formatter="{value}"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
)

line = (
    Line()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="Accept Rate",
        yaxis_index=1,
        y_axis=rate,
        label_opts=opts.LabelOpts(is_show=False),
    )
)

#
bar.overlap(line).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="acab104b5a69446892c0805148c620bc" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_acab104b5a69446892c0805148c620bc = echarts.init(
#                     document.getElementById('acab104b5a69446892c0805148c620bc'), 'white', {renderer: 'canvas'});
#                 var option_acab104b5a69446892c0805148c620bc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Submission",
#             "data": [
#                 1105,
#                 1219,
#                 1400,
#                 1467,
#                 1420,
#                 1678,
#                 1838,
#                 2403,
#                 3240,
#                 4856,
#                 6743
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Accepted",
#             "data": [
#                 263,
#                 293,
#                 308,
#                 366,
#                 359,
#                 441,
#                 403,
#                 569,
#                 678,
#                 1011,
#                 1429
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "Accept Rate",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2009",
#                     23.8
#                 ],
#                 [
#                     "2010",
#                     24.0
#                 ],
#                 [
#                     "2011",
#                     22.0
#                 ],
#                 [
#                     "2012",
#                     24.9
#                 ],
#                 [
#                     "2013",
#                     25.2
#                 ],
#                 [
#                     "2014",
#                     26.2
#                 ],
#                 [
#                     "2015",
#                     21.9
#                 ],
#                 [
#                     "2016",
#                     23.6
#                 ],
#                 [
#                     "2017",
#                     20.9
#                 ],
#                 [
#                     "2018",
#                     20.8
#                 ],
#                 [
#                     "2019",
#                     21.1
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Submission",
#                 "Accepted",
#                 "Accept Rate"
#             ],
#             "selected": {
#                 "Submission": true,
#                 "Accepted": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisPointer": {
#                 "show": true,
#                 "type": "shadow"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2009",
#                 "2010",
#                 "2011",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017",
#                 "2018",
#                 "2019"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "name": "Submission Number",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "interval": 1000,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 7000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "Accept Rate",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "interval": 20,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 100,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ]
# };
#                 chart_acab104b5a69446892c0805148c620bc.setOption(option_acab104b5a69446892c0805148c620bc);
#         });
#     </script>

# %% [markdown]
# # load data

# %%
with open('data/neurips2019.json') as fp:
    data_set = json.load(fp)

# %%
for i, title in enumerate(data_set):
    print("NO.%d" % i, "paper's title : ", title)
# Out:
# NO.0 paper's title :  Multimodal Model-Agnostic Meta-Learning via Task-Aware Modulation
# NO.1 paper's title :  ViLBERT: Pretraining Task-Agnostic Visiolinguistic Representations for Vision-and-Language Tasks
# NO.2 paper's title :  Stochastic Shared Embeddings: Data-driven Regularization of Embedding Layers
# NO.3 paper's title :  Unsupervised Scale-consistent Depth and Ego-motion Learning from Monocular Video
# NO.4 paper's title :  Zero-shot Learning via Simultaneous Generating and Learning
# NO.5 paper's title :  Ask not what AI can do for you, but what AI should do: Towards a framework of task delegability
# NO.6 paper's title :  Stand-Alone Self-Attention in Vision Models
# NO.7 paper's title :  High Fidelity Video Prediction with Large Neural Nets
# NO.8 paper's title :  Unsupervised learning of object structure and dynamics from videos
# NO.9 paper's title :  TensorPipe: Easy Scaling with Micro-Batch Pipeline Parallelism
# NO.10 paper's title :  Meta-Learning with Implicit Gradients
# NO.11 paper's title :  Adversarial Examples Are Not Bugs, They Are Features
# NO.12 paper's title :  Social-BiGAT: Multimodal Trajectory Forecasting using Bicycle-GAN and Graph Attention Networks
# NO.13 paper's title :  FreeAnchor: Learning to Match Anchors for Visual Object Detection
# NO.14 paper's title :  Differentially Private Hypothesis Selection
# NO.15 paper's title :  New Differentially Private Algorithms for Learning Mixtures of Well-Separated Gaussians
# NO.16 paper's title :  Average-Case Averages: Private Algorithms for Smooth Sensitivity and Mean Estimation
# NO.17 paper's title :  Multi-Resolution Weak Supervision for Sequential Data
# NO.18 paper's title :  DeepUSPS: Deep Robust Unsupervised Saliency Prediction via Self-supervision
# NO.19 paper's title :  The Point Where Reality Meets Fantasy: Mixed Adversarial Generators for Image Splice Detection
# NO.20 paper's title :  You Only Propagate Once: Accelerating Adversarial Training via Maximal Principle
# NO.21 paper's title :  Imitation Learning from Observations by Minimizing Inverse Dynamics Disagreement
# NO.22 paper's title :  Asymptotic Guarantees for Learning Generative Models with the Sliced-Wasserstein Distance
# NO.23 paper's title :  Generalized Sliced Wasserstein Distances
# NO.24 paper's title :  First Exit Time Analysis of Stochastic Gradient Descent Under Heavy-Tailed Gradient Noise
# NO.25 paper's title :  Blind Super-Resolution Kernel Estimation using an Internal-GAN
# NO.26 paper's title :  Noise-tolerant fair classification
# NO.27 paper's title :  Generalization in Generative Adversarial Networks: A Novel Perspective from Privacy Protection
# NO.28 paper's title :  Joint-task Self-supervised Learning for Temporal Correspondence
# NO.29 paper's title :  Provable Gradient Variance Guarantees for Black-Box Variational Inference
# NO.30 paper's title :  Divide and Couple: Using Monte Carlo Variational Objectives for Posterior Approximation
# NO.31 paper's title :  Experience Replay for Continual Learning
# NO.32 paper's title :  Deep ReLU Networks Have Surprisingly Few Activation Patterns
# NO.33 paper's title :  Chasing Ghosts: Instruction Following as Bayesian State Tracking
# NO.34 paper's title :  Block Coordinate Regularization by Denoising
# NO.35 paper's title :  Reducing Noise in GAN Training with Variance Reduced Extragradient
# NO.36 paper's title :  Learning Erdos-Renyi Random Graphs via Edge Detecting Queries
# NO.37 paper's title :  A Primal-Dual link between GANs and Autoencoders
# NO.38 paper's title :  muSSP: Efficient Min-cost Flow Algorithm for Multi-object Tracking
# NO.39 paper's title :  Category Anchor-Guided Unsupervised Domain Adaptation for Semantic Segmentation
# NO.40 paper's title :  Invert to Learn to Invert
# NO.41 paper's title :  Equitable Stable Matchings in Quadratic Time
# NO.42 paper's title :  Zero-Shot Semantic Segmentation
# NO.43 paper's title :  Metric Learning for Adversarial Robustness
# NO.44 paper's title :  DISN: Deep Implicit Surface Network for High-quality Single-view 3D Reconstruction
# NO.45 paper's title :  Batched Multi-armed Bandits Problem
# NO.46 paper's title :  vGraph: A Generative Model for Joint Community Detection and Node Representation Learning
# NO.47 paper's title :  Differentially Private Bayesian Linear Regression
# NO.48 paper's title :  Semantic Conditioned Dynamic Modulation for Temporal Sentence Grounding in Videos
# NO.49 paper's title :  AGEM: Solving Linear Inverse Problems via Deep Priors and Sampling
# NO.50 paper's title :  CPM-Nets: Cross Partial Multi-View Networks
# NO.51 paper's title :  Learning to Predict Layout-to-image Conditional Convolutions for Semantic Image Synthesis
# NO.52 paper's title :  Staying up to Date with Online Content Changes Using Reinforcement Learning for Scheduling
# NO.53 paper's title :  SySCD: A System-Aware Parallel Coordinate Descent Algorithm
# NO.54 paper's title :  Importance Weighted Hierarchical Variational Inference
# NO.55 paper's title :  RSN: Randomized Subspace Newton
# NO.56 paper's title :  Trust Region-Guided Proximal Policy Optimization
# NO.57 paper's title :  Adversarial Self-Defense for Cycle-Consistent GANs
# NO.58 paper's title :  Towards closing the gap between the theory and practice of SVRG
# NO.59 paper's title :  Uniform Error Bounds for Gaussian Process Regression with Application to Safe Control
# NO.60 paper's title :  ETNet: Error Transition Network for Arbitrary Style Transfer
# NO.61 paper's title :  No Pressure! Addressing the Problem of Local Minima in Manifold Learning Algorithms
# NO.62 paper's title :  Deep Equilibrium Models
# NO.63 paper's title :  Saccader: Accurate, Interpretable Image Classification with Hard Attention
# NO.64 paper's title :  Multiway clustering via tensor block models
# NO.65 paper's title :  Regret Minimization for Reinforcement Learning on Multi-Objective Online Markov Decision Processes
# NO.66 paper's title :  NAT: Neural Architecture Transformer for Accurate and Compact Architectures
# NO.67 paper's title :  Selecting Optimal Decisions via Distributionally Robust Nearest-Neighbor Regression
# NO.68 paper's title :  Network Pruning via Transformable Architecture Search
# NO.69 paper's title :  Differentiable Cloth Simulation for Inverse Problems
# NO.70 paper's title :  Poisson-randomized Gamma Dynamical Systems
# NO.71 paper's title :  Volumetric Correspondence Networks for Optical Flow
# NO.72 paper's title :  Learning Conditional Deformable Templates with Convolutional Networks
# NO.73 paper's title :  Fast Low-rank Metric Learning for Large-scale and High-dimensional Data
# NO.74 paper's title :  Efficient Symmetric Norm Regression via Linear Sketching
# NO.75 paper's title :  RUBi: Reducing Unimodal Biases in Visual Question Answering
# NO.76 paper's title :  Reducing Scene Bias of Convolutional Neural Networks for Human Action Understanding
# NO.77 paper's title :  NeurVPS: Neural Vanishing Point Scanning via Conic Convolution
# NO.78 paper's title :  DATA: Differentiable ArchiTecture Approximation
# NO.79 paper's title :  Learn, Imagine and Create: Text-to-Image Generation from Prior Knowledge
# NO.80 paper's title :  Memory-oriented Decoder for Light Field Salient Object Detection
# NO.81 paper's title :  Multi-label Co-regularization for Semi-supervised Facial Action Unit Recognition
# NO.82 paper's title :  Correlated Uncertainty for Learning Dense Correspondences from Noisy Labels
# NO.83 paper's title :  Powerset Convolutional Neural Networks
# NO.84 paper's title :  Optimal Pricing in Repeated Posted-Price Auctions with Different Patience of the Seller and the Buyer
# NO.85 paper's title :  An Accelerated Decentralized Stochastic Proximal Algorithm for Finite Sums
# NO.86 paper's title :  Efficient 3D Deep Learning via Point-Based Representation and Voxel-Based Convolution
# NO.87 paper's title :  Deep Learning without Weight Transport
# NO.88 paper's title :  Combinatorial Bandits with Relative Feedback
# NO.89 paper's title :  General Proximal Incremental Aggregated Gradient Algorithms: Better and Novel Results under General Scheme
# NO.90 paper's title :  Joint Optimizing of Cycle-Consistent Networks
# NO.91 paper's title :  Explicit Disentanglement of Appearance and Perspective in Generative Models
# NO.92 paper's title :  Polynomial Cost of Adaptation for X-Armed Bandits
# NO.93 paper's title :  Learning to Propagate for Graph Meta-Learning
# NO.94 paper's title :  Secretary Ranking with Minimal Inversions
# NO.95 paper's title :  Nonparametric Regressive Point Processes Based on Conditional Gaussian Processes
# NO.96 paper's title :  Learning Perceptual Inference by Contrasting
# NO.97 paper's title :  Selecting the independent coordinates of manifolds with large aspect ratios
# NO.98 paper's title :  Region-specific Diffeomorphic Metric Mapping
# NO.99 paper's title :  Subset Selection via Supervised Facility Location
# NO.100 paper's title :  Scene Representation Networks: Continuous 3D-Structure-Aware Neural Scene Representations
# NO.101 paper's title :  Reconciling λ-Returns with Experience Replay
# NO.102 paper's title :  Control Batch Size and Learning Rate to Generalize Well: Theoretical and Empirical Evidence
# NO.103 paper's title :  Non-Asymptotic Gap-Dependent Regret Bounds for Tabular MDPs
# NO.104 paper's title :  A Graph Theoretic Framework of Recomputation Algorithms for Memory-Efficient Backpropagation
# NO.105 paper's title :  Combinatorial Inference against Label Noise
# NO.106 paper's title :   Value Propagation for Decentralized Networked Deep Multi-agent  Reinforcement Learning
# NO.107 paper's title :  Convolution with even-sized kernels and symmetric padding
# NO.108 paper's title :  On The Classification-Distortion-Perception Tradeoff
# NO.109 paper's title :  Optimal Statistical Rates for Decentralised Non-Parametric Regression with Linear Speed-Up
# NO.110 paper's title :  Online sampling from log-concave distributions
# NO.111 paper's title :  Envy-Free Classification
# NO.112 paper's title :  Finding Friend and Foe in Multi-Agent Games
# NO.113 paper's title :  Computer Vision with a Single (Robust) Classifier
# NO.114 paper's title :  Gated CRF Loss for Weakly Supervised Semantic Image Segmentation
# NO.115 paper's title :  Model Compression with Adversarial Robustness: A Unified Optimization Framework
# NO.116 paper's title :  Neuron Communication Networks
# NO.117 paper's title :  CondConv: Conditionally Parameterized Convolutions for Efficient Inference
# NO.118 paper's title :  Regression Planning Networks
# NO.119 paper's title :  Twin Auxilary Classifiers GAN
# NO.120 paper's title :  Conditional Structure Generation through Graph Variational Generative Adversarial Nets
# NO.121 paper's title :  Distributional Policy Optimization: An Alternative Approach for Continuous Control
# NO.122 paper's title :  Sampling Sketches for Concave Sublinear Functions of Frequencies
# NO.123 paper's title :  Deliberative Explanations: visualizing network insecurities
# NO.124 paper's title :  Computing Full Conformal Prediction Set with Approximate Homotopy
# NO.125 paper's title :  Failing Loudly: An Empirical Study of Methods for Detecting Dataset Shift
# NO.126 paper's title :  Hierarchical Reinforcement Learning with Advantage-Based Auxiliary Rewards
# NO.127 paper's title :  Multi-View Reinforcement Learning
# NO.128 paper's title :  Cascade RPN: Delving into High-Quality Region Proposal Network with Adaptive Convolution
# NO.129 paper's title :  Neural Diffusion Distance for Image Segmentation
# NO.130 paper's title :  Fine-grained Optimization of Deep Neural Networks
# NO.131 paper's title :  Extending Stein’s Unbiased Risk Estimator To Train Deep Denoisers with Correlated Pairs of Noisy Images
# NO.132 paper's title :  Wibergian Learning of Continuous Energy Functions
# NO.133 paper's title :  Hyperspherical Prototype Networks
# NO.134 paper's title :  Expressive power of tensor-network factorizations for probabilistic modelling
# NO.135 paper's title :  HyperGCN: A New Method For Training Graph Convolutional Networks on Hypergraphs
# NO.136 paper's title :  SSRGD: Simple Stochastic Recursive Gradient Descent for Escaping Saddle Points
# NO.137 paper's title :  Efficient Meta Learning via Minibatch Proximal Update
# NO.138 paper's title :  Unconstrained Monotonic Neural Networks
# NO.139 paper's title :  Guided Similarity Separation for Image Retrieval
# NO.140 paper's title :  Learning Imbalanced Datasets with Label-Distribution-Aware Margin Loss
# NO.141 paper's title :  Strategizing against No-regret Learners
# NO.142 paper's title :  D-VAE: A Variational Autoencoder for Directed Acyclic Graphs
# NO.143 paper's title :  Hierarchical Optimal Transport for Document Representation
# NO.144 paper's title :  Multivariate Sparse Coding of Nonstationary Covariances with Gaussian Processes
# NO.145 paper's title :  Positional Normalization
# NO.146 paper's title :  A New Defense Against Adversarial Images: Turning a Weakness into a Strength
# NO.147 paper's title :  Quadratic Video Interpolation
# NO.148 paper's title :  ResNets Ensemble via the Feynman-Kac Formalism to Improve Natural and Robust Accuracies
# NO.149 paper's title :  Incremental Scene Synthesis
# NO.150 paper's title :  Self-Supervised Generalisation with Meta Auxiliary Learning
# NO.151 paper's title :  Variational Denoising Network: Toward Blind Noise Modeling and Removal
# NO.152 paper's title :  Fast Sparse Group Lasso
# NO.153 paper's title :  Learnable Tree Filter for Structure-preserving Feature Transform
# NO.154 paper's title :  Data-Dependence of Plateau Phenomenon in Learning with Neural Network --- Statistical Mechanical Analysis
# NO.155 paper's title :  Coordinated hippocampal-entorhinal replay as structural inference
# NO.156 paper's title :  Cascaded Dilated Dense Network with Two-step Data Consistency for MRI Reconstruction
# NO.157 paper's title :  On the Ineffectiveness of Variance Reduced Optimization for Deep Learning
# NO.158 paper's title :  On the Curved Geometry of Accelerated Optimization
# NO.159 paper's title :  Multi-marginal Wasserstein GAN
# NO.160 paper's title :  Better Exploration with Optimistic Actor Critic
# NO.161 paper's title :  Importance Resampling for Off-policy Prediction
# NO.162 paper's title :  The Label Complexity of Active Learning from Observational Data
# NO.163 paper's title :  Meta-Learning Representations for Continual Learning
# NO.164 paper's title :  Defense Against Adversarial Attacks Using Feature Scattering-based Adversarial Training
# NO.165 paper's title :  Visualizing the PHATE of Neural Networks
# NO.166 paper's title :  The Cells Out of Sample (COOS) dataset and benchmarks for measuring out-of-sample generalization of image classifiers
# NO.167 paper's title :  Nonconvex Low-Rank Tensor Completion from Noisy Data
# NO.168 paper's title :  Beyond Online Balanced Descent: An Optimal Algorithm for Smoothed Online Optimization
# NO.169 paper's title :  Channel Gating Neural Networks
# NO.170 paper's title :  Neural networks grown and self-organized by noise
# NO.171 paper's title :  Catastrophic Forgetting Meets Negative Transfer: Batch Spectral Shrinkage for Safe Transfer Learning
# NO.172 paper's title :  Meta-Weight-Net: Learning an Explicit Mapping For Sample Weighting
# NO.173 paper's title :  Variational Structured Semantic Inference for Diverse Image Captioning
# NO.174 paper's title :  Mapping State Space using Landmarks for Universal Goal Reaching
# NO.175 paper's title :  Transferable Normalization: Towards Improving Transferability of Deep Neural Networks
# NO.176 paper's title :  Random deep neural networks are biased towards simple functions
# NO.177 paper's title :  XNAS: Neural Architecture Search with Expert Advice
# NO.178 paper's title :  CNN^{2}: Viewpoint Generalization via a Binocular Vision
# NO.179 paper's title :   Generalized Off-Policy Actor-Critic
# NO.180 paper's title :  DAC: The Double Actor-Critic Architecture for Learning Options
# NO.181 paper's title :  Numerically Accurate Hyperbolic Embeddings Using Tiling-Based Models
# NO.182 paper's title :  Controlling Neural Level Sets
# NO.183 paper's title :  Blended Matching Pursuit
# NO.184 paper's title :  An Improved Analysis of Training Over-parameterized Deep Neural Networks
# NO.185 paper's title :  Controllable Text to Image Generation
# NO.186 paper's title :  Improving Textual Network Learning with Variational Homophilic Embeddings
# NO.187 paper's title :  Rethinking Generative Coverage: A Pointwise Guaranteed Approach
# NO.188 paper's title :  The Randomized Midpoint Method for Log-Concave Sampling
# NO.189 paper's title :  Sample-Efficient Deep Reinforcement Learning via Episodic Backward Update
# NO.190 paper's title :  Fully Neural Network based Model for General Temporal Point Processes
# NO.191 paper's title :  Gate Decorator: Global Filter Pruning Method for Accelerating Deep Convolutional Neural Networks
# NO.192 paper's title :  Discrimination in Online Markets: Effects of Social Bias on Learning from Reviews and Policy Design
# NO.193 paper's title :  Provably Powerful Graph Networks
# NO.194 paper's title :  Order Optimal One-Shot Distributed Learning
# NO.195 paper's title :  Information Competing Process for Learning Diversified Representations
# NO.196 paper's title :  GENO -- GENeric Optimization for Classical Machine Learning
# NO.197 paper's title :  Conditional Independence Testing using Generative Adversarial Networks
# NO.198 paper's title :  Online Stochastic Shortest Path with Bandit Feedback and Unknown Transition Function
# NO.199 paper's title :  Partitioning Structure Learning for Segmented Linear Regression Trees
# NO.200 paper's title :  A Tensorized Transformer for Language Modeling
# NO.201 paper's title :  Kernel Stein Tests for Multiple Model Comparison
# NO.202 paper's title :  Disentangled behavioural representations
# NO.203 paper's title :  More Is Less: Learning Efficient Video Representations by Temporal Aggregation Module
# NO.204 paper's title :  Rethinking the CSC Model for Natural Images
# NO.205 paper's title :  Integrating Generative and Discriminative Sparse Kernel Machines for  Multi-class Active Learning
# NO.206 paper's title :  Learning to Control Self-Assembling Morphologies: A Study of Generalization via Modularity
# NO.207 paper's title :  Perceiving the arrow of time in autoregressive motion
# NO.208 paper's title :  DualDICE: Behavior-Agnostic Estimation of Discounted Stationary Distribution Corrections
# NO.209 paper's title :  Hyper-Graph-Network Decoders for Block Codes
# NO.210 paper's title :  Large Scale Markov Decision Processes with Changing Rewards
# NO.211 paper's title :  Multiview Aggregation for Learning Category-Specific Shape Reconstruction
# NO.212 paper's title :  Semi-Parametric Dynamic Contextual Pricing
# NO.213 paper's title :  Nearly Linear-Time, Deterministic Algorithm for Maximizing (Non-Monotone) Submodular Functions Under Cardinality Constraint
# NO.214 paper's title :  Initialization of ReLUs for Dynamical Isometry
# NO.215 paper's title :  Gradient Information for Representation and Modeling
# NO.216 paper's title :  SpiderBoost and Momentum: Faster Variance Reduction Algorithms
# NO.217 paper's title :  Minimax rates of estimating approximate differential privacy
# NO.218 paper's title :  Backprop with Approximate Activations for Memory-efficient Network Training
# NO.219 paper's title :  Training Image Estimators without Image Ground Truth
# NO.220 paper's title :  Deep Structured Prediction for Facial Landmark Detection
# NO.221 paper's title :  Information-Theoretic Confidence Bounds for Reinforcement Learning
# NO.222 paper's title :  Transfer Anomaly Detection by Inferring Latent Domain Representations
# NO.223 paper's title :  Total Least Squares Regression in Input Sparsity Time
# NO.224 paper's title :  Park: An Open Platform for Learning-Augmented Computer Systems
# NO.225 paper's title :  Adapting Neural Networks for the Estimation of Treatment Effects
# NO.226 paper's title :  Learning Transferable Graph Exploration
# NO.227 paper's title :  Conformal Prediction Under Covariate Shift
# NO.228 paper's title :  Optimal Analysis of Subset-Selection Based L_p Low-Rank Approximation
# NO.229 paper's title :  Asymmetric Valleys: Beyond Sharp and Flat Local Minima
# NO.230 paper's title :  Positive-Unlabeled Compression on the Cloud
# NO.231 paper's title :  Direct Estimation of Differential Functional Graphical Model
# NO.232 paper's title :  On the Calibration of Multiclass Classification  with Rejection
# NO.233 paper's title :  Third-Person Visual Imitation Learning via Decoupled Hierarchical Control
# NO.234 paper's title :  Stagewise Training Accelerates Convergence of Testing Error Over SGD
# NO.235 paper's title :  Learning Robust Options by Conditional Value at Risk Optimization
# NO.236 paper's title :  Non-asymptotic Analysis of Stochastic Methods for Non-Smooth Non-Convex Regularized Problems
# NO.237 paper's title :  On Learning Over-parameterized Neural Networks: A Functional Approximation Prospective
# NO.238 paper's title :  Drill-down: Interactive Retrieval of Complex Scenes using Natural Language Queries
# NO.239 paper's title :  Visual Sequence Learning  in Hierarchical Prediction Networks and Primate Visual Cortex
# NO.240 paper's title :  Dual Variational Generation for Low Shot Heterogeneous Face Recognition
# NO.241 paper's title :  Discovering Neural Wirings
# NO.242 paper's title :  On the Optimality of Perturbations in Stochastic and Adversarial Multi-armed Bandit Problems
# NO.243 paper's title :  Knowledge Extraction with No Observable Data
# NO.244 paper's title :  PAC-Bayes under potentially heavy tails
# NO.245 paper's title :  One-Shot Object Detection with Co-Attention and Co-Excitation
# NO.246 paper's title :  Quaternion Knowledge Graph Embeddings
# NO.247 paper's title :  Glyce: Glyph-vectors for Chinese Character Representations
# NO.248 paper's title :  Turbo Autoencoder: Deep learning based channel code for point-to-point communication channels
# NO.249 paper's title :  Heterogeneous Graph Learning for Visual Commonsense Reasoning
# NO.250 paper's title :  Probabilistic Watershed: Sampling all spanning forests for seeded segmentation and semi-supervised learning
# NO.251 paper's title :  Classification-by-Components: Probabilistic Modeling of Reasoning over a Set of Components
# NO.252 paper's title :  Identifying Causal Effects via Context-specific Independence Relations
# NO.253 paper's title :  Bridging Machine Learning and Logical Reasoning by Abductive Learning
# NO.254 paper's title :  Regret Minimization for Reinforcement Learning by Evaluating the Optimal Bias Function
# NO.255 paper's title :  On the Global Convergence of (Fast) Incremental Expectation Maximization Methods
# NO.256 paper's title :  A Linearly Convergent Proximal Gradient Algorithm for Decentralized  Optimization
# NO.257 paper's title :  Regularizing Trajectory Optimization with Denoising Autoencoders
# NO.258 paper's title :  Learning Hierarchical Priors in VAEs
# NO.259 paper's title :  Epsilon-Best-Arm Identification in Pay-Per-Reward Multi-Armed Bandits
# NO.260 paper's title :  Safe Exploration for Interactive Machine Learning
# NO.261 paper's title :  Addressing Failure Detection by Learning Model Confidence
# NO.262 paper's title :  Combinatorial Bayesian Optimization using the Graph Cartesian Product
# NO.263 paper's title :  Fooling Neural Network Interpretations via Adversarial Model Manipulation
# NO.264 paper's title :  On Lazy Training in Differentiable Programming
# NO.265 paper's title :  Quality Aware Generative Adversarial Networks
# NO.266 paper's title :  Copula-like Variational Inference
# NO.267 paper's title :  Implicit Regularization for Optimal Sparse Recovery
# NO.268 paper's title :  Locally Private Gaussian Estimation
# NO.269 paper's title :  Multi-mapping Image-to-Image Translation via Learning Disentanglement
# NO.270 paper's title :  Spatially Aggregated Gaussian Processes with Multivariate Areal Outputs
# NO.271 paper's title :  Structured Decoding for Non-Autoregressive Machine Translation
# NO.272 paper's title :  Learning Temporal Pose Estimation from Sparsely-Labeled Videos
# NO.273 paper's title :  Greedy InfoMax for Biologically Plausible Self-Supervised Representation Learning
# NO.274 paper's title :  Scalable Gromov-Wasserstein Learning for Graph Partitioning and Matching
# NO.275 paper's title :  Meta-Reinforced Synthetic Data for One-Shot Fine-Grained Visual Recognition
# NO.276 paper's title :  Real-Time Reinforcement Learning
# NO.277 paper's title :  Robust Multi-agent Counterfactual Prediction
# NO.278 paper's title :  Approximate Inference Turns Deep Networks into Gaussian Processes
# NO.279 paper's title :  Deep Signatures
# NO.280 paper's title :  Individual Regret in Cooperative Nonstochastic Multi-Armed Bandits
# NO.281 paper's title :  Convergent Policy Optimization for Safe Reinforcement Learning
# NO.282 paper's title :  Augmented Neural ODEs
# NO.283 paper's title :  Thompson Sampling for Multinomial Logit Contextual Bandits
# NO.284 paper's title :  Backpropagation-Friendly Eigendecomposition
# NO.285 paper's title :  FastSpeech: Fast, Robust and Controllable Text to Speech
# NO.286 paper's title :  Ultrametric Fitting by Gradient Descent
# NO.287 paper's title :  Distinguishing Distributions When Samples Are Strategically Transformed
# NO.288 paper's title :  Implicit Regularization of Discrete Gradient Dynamics in Deep Linear Neural Networks
# NO.289 paper's title :  Deep Set Prediction Networks
# NO.290 paper's title :  DppNet: Approximating Determinantal Point Processes with Deep Networks
# NO.291 paper's title :  Efficient Communication in Multi-Agent Reinforcement Learning via Variance Based Control
# NO.292 paper's title :  Neural Lyapunov Control
# NO.293 paper's title :  Fully Dynamic Consistent Facility Location
# NO.294 paper's title :  A Stickier Benchmark for General-Purpose Language Understanding Systems
# NO.295 paper's title :  A Flexible Generative Framework for Graph-based Semi-supervised Learning
# NO.296 paper's title :  Self-normalization in Stochastic Neural Networks
# NO.297 paper's title :  Optimal Decision Tree with Noisy Outcomes
# NO.298 paper's title :  Meta-Curvature
# NO.299 paper's title :  Intrinsically Efficient, Stable, and Bounded Off-Policy Evaluation for Reinforcement Learning
# NO.300 paper's title :  KerGM: Kernelized Graph Matching
# NO.301 paper's title :  Transfusion: Understanding Transfer Learning for Medical Imaging
# NO.302 paper's title :  Adversarial training for free!
# NO.303 paper's title :  Communication-Efficient Distributed Learning via Lazily Aggregated Quantized Gradients
# NO.304 paper's title :  Implicitly learning to reason in first-order logic
# NO.305 paper's title :  Kernel-Based Approaches for Sequence Modeling: Connections to Neural Methods
# NO.306 paper's title :  PC-Fairness: A Unified Framework for Measuring Causality-based Fairness
# NO.307 paper's title :  Arbicon-Net: Arbitrary Continuous Geometric Transformation Networks for Image Registration
# NO.308 paper's title :  Assessing Disparate Impact of Personalized Interventions: Identifiability and Bounds
# NO.309 paper's title :  The Fairness of Risk Scores Beyond Classification: Bipartite Ranking and the XAUC Metric
# NO.310 paper's title :  HYPE: A Benchmark for Human eYe Perceptual Evaluation of Generative Models
# NO.311 paper's title :  First order expansion of convex regularized estimators
# NO.312 paper's title :  Capacity Bounded Differential Privacy
# NO.313 paper's title :  Universal Boosting Variational Inference
# NO.314 paper's title :  SGD on Neural Networks Learns Functions of Increasing Complexity
# NO.315 paper's title :  The Landscape of Non-convex Empirical Risk with Degenerate Population Risk
# NO.316 paper's title :  Making AI Forget You: Data Deletion in Machine Learning
# NO.317 paper's title :  Practical Differentially Private Top-k Selection with Pay-what-you-get Composition
# NO.318 paper's title :  Conformalized Quantile Regression
# NO.319 paper's title :  Thompson Sampling with Information Relaxation Penalties
# NO.320 paper's title :  Deep Generalized Method of Moments for Instrumental Variable Analysis
# NO.321 paper's title :  Learning Sample-Specific Models with Low-Rank Personalized Regression
# NO.322 paper's title :  Dance to Music
# NO.323 paper's title :  Deconstructing Lottery Tickets: Zeros, Signs, and the Supermask
# NO.324 paper's title :  Implicit Generation and Modeling with Energy Based Models
# NO.325 paper's title :  Who Learns? Decomposing Learning into Per-Parameter Loss Contribution
# NO.326 paper's title :  Predicting the Politics of an Image Using Webly Supervised Data
# NO.327 paper's title :  Adaptive GNN for Image Analysis and Editing
# NO.328 paper's title :  Ultra Fast Medoid Identification via Correlated Sequential Halving
# NO.329 paper's title :  Tight Dimension Independent Lower Bound on the Expected Convergence Rate for Diminishing Step Sizes in SGD
# NO.330 paper's title :  Asymptotics for Sketching in Least Squares Regression
# NO.331 paper's title :  MCP: Learning Composable Hierarchical Control with Multiplicative Compositional Policies
# NO.332 paper's title :  Exact inference in structured prediction
# NO.333 paper's title :  Coda: An End-to-End Neural Program Decompiler
# NO.334 paper's title :  Bat-G net: Bat-inspired High-Resolution 3D Image Reconstruction using Ultrasonic Echoes
# NO.335 paper's title :  Painless Stochastic Gradient: Interpolation, Line-Search, and Convergence Rates
# NO.336 paper's title :  Scalable Structure Learning of Continuous-Time Bayesian Networks from Incomplete Data
# NO.337 paper's title :  Privacy-Preserving Classification of Personal Text Messages with Secure Multi-Party Computation
# NO.338 paper's title :  Efficiently Estimating Erdos-Renyi Graphs with Node Differential Privacy
# NO.339 paper's title :  Learning Representations for Time Series Clustering
# NO.340 paper's title :  Variance Reduced Uncertainty Calibration
# NO.341 paper's title :  A Normative Theory for Causal Inference and Bayes Factor Computation in Neural Circuits
# NO.342 paper's title :  Unsupervised Keypoint Learning for Guiding Class-conditional Video Prediction
# NO.343 paper's title :  Subspace Attack: Exploiting Promising Subspaces for Query-Efficient Black-box Attacks
# NO.344 paper's title :  Stochastic Gradient Hamiltonian Monte Carlo Methods with Recursive Variance Reduction
# NO.345 paper's title :  Learning Latent Process from High-Dimensional Event Sequences via Efficient Sampling
# NO.346 paper's title :  Cross-sectional Learning of Extremal Dependence among Financial Assets
# NO.347 paper's title :  Principal Component Projection and Regression in Nearly Linear Time through Asymmetric SVRG
# NO.348 paper's title :  Compression with Flows via Local Bits-Back Coding
# NO.349 paper's title :  Exact Rate-Distortion in Autoencoders via Echo Noise
# NO.350 paper's title :  iSplit LBI: Individualized Partial Ranking with Ties via Split LBI
# NO.351 paper's title :  Self-Supervised Active Triangulation for 3D Human Pose Reconstruction
# NO.352 paper's title :  MetaQuant: Learning to Quantize by Learning to Penetrate Non-differentiable Quantization
# NO.353 paper's title :  Improved Precision and Recall Metric for Assessing Generative Models
# NO.354 paper's title :  A First-order Algorithmic Framework for Distributionally Robust Logistic Regression
# NO.355 paper's title :  PasteGAN: A Semi-Parametric Method to Generate Image from Scene Graph
# NO.356 paper's title :  Concomitant Lasso with Repetitions (CLaR): beyond averaging multiple realizations of heteroscedastic noise
# NO.357 paper's title :  Joint Optimization of Tree-based Index and Deep Model for Recommender Systems
# NO.358 paper's title :  Learning Generalizable Device Placement Algorithms for Distributed Machine Learning
# NO.359 paper's title :  Uncoupled Regression from Pairwise Comparison Data
# NO.360 paper's title :  Cross Attention Network for Few-shot Classification
# NO.361 paper's title :  A Nonconvex Approach for Exact and Efficient Multichannel Sparse Blind Deconvolution
# NO.362 paper's title :  SCAN: A Scalable Neural Networks Framework Towards Compact and Efficient Models
# NO.363 paper's title :  Revisiting the Bethe-Hessian: Improved Community Detection in Sparse Heterogeneous Graphs
# NO.364 paper's title :  Teaching Multiple Concepts to a Forgetful Learner
# NO.365 paper's title :  Regularized Weighted Low Rank Approximation
# NO.366 paper's title :  Practical and Consistent Estimation of f-Divergences
# NO.367 paper's title :  Approximation Ratios of Graph Neural Networks for Combinatorial Problems
# NO.368 paper's title :  Thinning for Accelerating the Learning of Point Processes
# NO.369 paper's title :  A Prior of a Googol Gaussians: a Tensor Ring Induced Prior for Generative Models
# NO.370 paper's title :  Differentially Private Markov Chain Monte Carlo
# NO.371 paper's title :  Full-Gradient Representation for Neural Network Visualization
# NO.372 paper's title :  q-means: A quantum algorithm for unsupervised machine learning
# NO.373 paper's title :  Learner-aware Teaching: Inverse Reinforcement Learning with Preferences and Constraints
# NO.374 paper's title :  Limitations of the empirical Fisher approximation
# NO.375 paper's title :  Flow-based Image-to-Image Translation with Feature Disentanglement
# NO.376 paper's title :  Learning dynamic semi-algebraic proofs
# NO.377 paper's title :  Shape and Time Distorsion Loss for Training Deep Time Series Forecasting Models
# NO.378 paper's title :  Understanding attention in graph neural networks
# NO.379 paper's title :  Data Cleansing for Models Trained with SGD
# NO.380 paper's title :  Curvilinear Distance Metric Learning
# NO.381 paper's title :  Semantically-Regularized Logic Graph Embeddings
# NO.382 paper's title :  Modeling Uncertainty by Learning A Hierarchy of Deep Neural Connections
# NO.383 paper's title :  Efficient Graph Generation with Graph Recurrent Attention Networks
# NO.384 paper's title :  Beyond Alternating Updates for Matrix Factorization with Inertial Bregman Proximal Gradient Algorithms
# NO.385 paper's title :  Learning Deep Bilinear Transformation for Fine-grained Image Representation
# NO.386 paper's title :  Practical Deep Learning with Bayesian Principles
# NO.387 paper's title :  Training Language GANs from Scratch
# NO.388 paper's title :  Pseudo-Extended Markov chain Monte Carlo
# NO.389 paper's title :  Differentially Private Bagging: Improved utility and cheaper privacy than subsample-and-aggregate
# NO.390 paper's title :  Propagating Uncertainty in Reinforcement Learning via Wasserstein Barycenters
# NO.391 paper's title :  On Adversarial Mixup Resynthesis
# NO.392 paper's title :  A Geometric Perspective on Optimal Representations for Reinforcement Learning
# NO.393 paper's title :  Learning New Tricks From Old Dogs: Multi-Source Transfer Learning From Pre-Trained Networks
# NO.394 paper's title :  Understanding and Improving Layer Normalization
# NO.395 paper's title :  Uncertainty-based Continual Learning with Adaptive Regularization
# NO.396 paper's title :  LIIR: Learning Individual Intrinsic Reward in Multi-Agent Reinforcement Learning
# NO.397 paper's title :  U-Time: A Fully Convolutional Network for Time Series Segmentation Applied to Sleep Staging
# NO.398 paper's title :  Massively scalable Sinkhorn distances via the Nyström method
# NO.399 paper's title :  Double Quantization for Communication-Efficient Distributed Optimization
# NO.400 paper's title :  Globally optimal score-based learning of directed acyclic graphs in high-dimensions
# NO.401 paper's title :  Multi-relational Poincaré Graph Embeddings
# NO.402 paper's title :  No-Press Diplomacy: Modeling Multi-Agent Gameplay
# NO.403 paper's title :  State Aggregation Learning from Markov Transition Data
# NO.404 paper's title :  Disentangling Influence: Using disentangled representations to audit model predictions
# NO.405 paper's title :  Successor Uncertainties: Exploration and Uncertainty in Temporal Difference Learning
# NO.406 paper's title :  Partially Encrypted Deep Learning using Functional Encryption
# NO.407 paper's title :  Decentralized Cooperative Stochastic Bandits
# NO.408 paper's title :  Statistical bounds for entropic optimal transport: sample complexity and the central limit theorem
# NO.409 paper's title :  Efficient Deep Approximation of GMMs
# NO.410 paper's title :  Learning low-dimensional state embeddings and metastable clusters from time series data
# NO.411 paper's title :  Exploiting Local and Global Structure for Point Cloud Semantic Segmentation with Contextual Point Representations
# NO.412 paper's title :  Scalable Bayesian dynamic covariance modeling with variational Wishart and inverse Wishart processes
# NO.413 paper's title :  Kernel Instrumental Variable Regression
# NO.414 paper's title :  Symmetry-Based Disentangled Representation Learning requires Interaction with Environments
# NO.415 paper's title :  Fast Efficient Hyperparameter Tuning for Policy Gradient Methods
# NO.416 paper's title :  Offline Contextual Bayesian Optimization
# NO.417 paper's title :  Making the Cut: A Bandit-based Approach to Tiered Interviewing
# NO.418 paper's title :  Unsupervised Scalable Representation Learning for Multivariate Time Series
# NO.419 paper's title :  A state-space model for inferring effective connectivity of latent neural dynamics from simultaneous EEG/fMRI
# NO.420 paper's title :  End to end learning and optimization on graphs
# NO.421 paper's title :  Game Design for Eliciting Distinguishable Behavior
# NO.422 paper's title :  When does label smoothing help?
# NO.423 paper's title :  Finite-Time Performance Bounds and Adaptive Learning Rate Selection for Two Time-Scale Reinforcement Learning
# NO.424 paper's title :  Rethinking Deep Neural Network Ownership Verification: Embedding Passports to Defeat Ambiguity Attacks
# NO.425 paper's title :  Scalable Spike Source Localization in Extracellular Recordings using Amortized Variational Inference
# NO.426 paper's title :  Optimal Sketching for Kronecker Product Regression and Low Rank Approximation
# NO.427 paper's title :  Distribution-Independent PAC Learning of Halfspaces with Massart Noise
# NO.428 paper's title :  The Convergence Rate of Neural Networks for Learned Functions of Different Frequencies
# NO.429 paper's title :  Online Learning for Auxiliary Task Weighting for Reinforcement Learning
# NO.430 paper's title :  Blocking Bandits
# NO.431 paper's title :  Global Convergence of Least Squares EM for Demixing Two Log-Concave Densities
# NO.432 paper's title :  Prior-Free Dynamic Auctions with Low Regret Buyers
# NO.433 paper's title :  On Single Source Robustness in Deep Fusion Models
# NO.434 paper's title :  Policy Evaluation with Latent Confounders via Optimal Balance
# NO.435 paper's title :  Think Globally, Act Locally: A Deep Neural Network Approach to High-Dimensional Time Series Forecasting
# NO.436 paper's title :  Adaptive Cross-Modal Few-shot Learning
# NO.437 paper's title :  Spectral Modification of Graphs for Improved Spectral Clustering
# NO.438 paper's title :  Hyperbolic Graph Convolutional Neural Networks
# NO.439 paper's title :  Cost Effective Active Search
# NO.440 paper's title :  Exploration Bonus for Regret Minimization in Discrete and Continuous Average Reward MDPs
# NO.441 paper's title :  Hybrid 8-bit Floating Point (HFP8) Training and Inference for Deep Neural Networks
# NO.442 paper's title :  A Stratified Approach to Robustness for Randomly Smoothed Classifiers
# NO.443 paper's title :  Poisson-Minibatching for Gibbs Sampling with Convergence Rate Guarantees
# NO.444 paper's title :  One ticket to win them all: generalizing lottery ticket initializations across datasets and optimizers
# NO.445 paper's title :  Breaking the Glass Ceiling for Embedding-Based Classifiers for Large Output Spaces
# NO.446 paper's title :  Fair Algorithms for Clustering
# NO.447 paper's title :  Learning Mean-Field Games
# NO.448 paper's title :  SpArSe: Sparse Architecture Search for CNNs on Resource-Constrained Microcontrollers
# NO.449 paper's title :  Deep imitation learning for molecular inverse problems
# NO.450 paper's title :  Visual Concept-Metaconcept Learning
# NO.451 paper's title :  Adaptive Video-to-Video Synthesis via Network Weight Generation
# NO.452 paper's title :  Neural Similarity Learning
# NO.453 paper's title :  Ordered Memory
# NO.454 paper's title :  MixMatch: A Holistic Approach to Semi-Supervised Learning
# NO.455 paper's title :  Deep Multivariate Quantiles for Novelty Detection
# NO.456 paper's title :  Fast Parallel Algorithms for Statistical Subset Selection Problems
# NO.457 paper's title :  PHYRE: A New Benchmark for Physical Reasoning
# NO.458 paper's title :  How many variables should be entered in a principal component regression equation?
# NO.459 paper's title :  Factor Group-Sparse Regularization for Efficient Low-Rank Matrix Recovery
# NO.460 paper's title :  Mutually Regressive Point Processes
# NO.461 paper's title :  Data-driven Estimation of Sinusoid Frequencies
# NO.462 paper's title :  E2-Train: Energy-Efficient Deep Network Training with Data-, Model-, and Algorithm-Level Saving
# NO.463 paper's title :  ANODEV2: A Coupled Neural ODE Framework
# NO.464 paper's title :  Estimating Entropy of Distributions in Constant Space
# NO.465 paper's title :  On the Utility of Learning about Humans for Human-AI Coordination
# NO.466 paper's title :  Efficient Regret Minimization Algorithm for Extensive-Form Correlated Equilibrium
# NO.467 paper's title :  Learning in Generalized  Linear Contextual Bandits with Stochastic Delays
# NO.468 paper's title :  Empirically Measuring Concentration: Fundamental Limits on Intrinsic Robustness
# NO.469 paper's title :  Optimistic Regret Minimization for Extensive-Form Games via Dilated Distance-Generating Functions
# NO.470 paper's title :  On Learning Non-Convergent Non-Persistent Short-Run MCMC Toward Energy-Based Model
# NO.471 paper's title :  Enhancing the Locality and Breaking the Memory Bottleneck of Transformer on Time Series Forecasting
# NO.472 paper's title :  On the Accuracy of Influence Functions for Measuring Group Effects
# NO.473 paper's title :  Face Reconstruction from Voice using Generative Adversarial Networks
# NO.474 paper's title :  Incremental Few-Shot Learning with Attention Attractor Networks
# NO.475 paper's title :  On Testing for Biases in Peer Review
# NO.476 paper's title :  Learning Disentangled Representation for Robust Person Re-identification
# NO.477 paper's title :  Balancing Efficiency and Fairness in On-Demand Ridesourcing
# NO.478 paper's title :  Latent Ordinary Differential Equations for Irregularly-Sampled Time Series
# NO.479 paper's title :  Deep RGB-D Canonical Correlation Analysis For Sparse Depth Completion
# NO.480 paper's title :  Input Similarity from the Neural Network Perspective
# NO.481 paper's title :  Adaptive Sequence Submodularity
# NO.482 paper's title :  Weight Agnostic Neural Networks
# NO.483 paper's title :  Learning to Predict Without Looking Ahead: World Models Without Forward Prediction
# NO.484 paper's title :  Reducing the variance in online optimization by transporting past gradients
# NO.485 paper's title :  Characterizing Bias in Classifiers using Generative Models
# NO.486 paper's title :  Optimal Stochastic and Online Learning with Individual Iterates
# NO.487 paper's title :  Policy Learning for Fairness in Ranking
# NO.488 paper's title :  Off-Policy Evaluation of Generalization for Deep Q-Learning in Binary Reward Tasks
# NO.489 paper's title :  Regularized Gradient Boosting
# NO.490 paper's title :  Efficient Probabilistic Inference in the Quest for Physics Beyond the Standard Model
# NO.491 paper's title :   Markov Random Fields for Collaborative Filtering
# NO.492 paper's title :  A Step Toward Quantifying Independently Reproducible Machine Learning Research
# NO.493 paper's title :  Scalable Global Optimization via Local Bayesian Optimization
# NO.494 paper's title :  Time-series Generative Adversarial Networks
# NO.495 paper's title :  On Accelerating Training of Transformer-Based Language Models
# NO.496 paper's title :  A Refined Margin Distribution Analysis for Forest Representation Learning
# NO.497 paper's title :  Robustness to Adversarial Perturbations in Learning from Incomplete Data
# NO.498 paper's title :  Exploring Unexplored Tensor Decompositions for Convolutional Neural Networks
# NO.499 paper's title :  An Adaptive Empirical  Bayesian Method for Sparse Deep Learning
# NO.500 paper's title :  Adaptive Influence Maximization with Myopic Feedback
# NO.501 paper's title :  Focused Quantization for Sparse CNNs
# NO.502 paper's title :  Quantum Embedding of Knowledge for Reasoning
# NO.503 paper's title :  Optimal Best Markovian Arm Identification with Fixed Confidence
# NO.504 paper's title :  Limiting Extrapolation in Linear Approximate Value Iteration
# NO.505 paper's title :  Almost Horizon-Free Structure-Aware Best Policy Identification with a Generative Model
# NO.506 paper's title :  Invertible Convolutional Flow
# NO.507 paper's title :  A Latent Variational Framework for Stochastic Optimization
# NO.508 paper's title :  Topology-Preserving Deep Image Segmentation
# NO.509 paper's title :  Connective Cognition Network for Directional Visual Commonsense Reasoning
# NO.510 paper's title :  Online Markov Decoding: Lower Bounds and Near-Optimal Approximation Algorithms
# NO.511 paper's title :  A Meta-MDP Approach to Exploration for Lifelong Reinforcement Learning
# NO.512 paper's title :  Push-pull Feedback Implements Hierarchical Information Retrieval Efficiently
# NO.513 paper's title :  Learning Disentangled Representations for Recommendation
# NO.514 paper's title :  Graph Neural Tangent Kernel: Fusing Graph Neural Networks with Graph Kernels
# NO.515 paper's title :  In-Place Near Zero-Cost Memory Protection for DNN
# NO.516 paper's title :  Acceleration via Symplectic Discretization of High-Resolution Differential Equations
# NO.517 paper's title :  XLNet: Generalized Autoregressive Pretraining for Language Understanding
# NO.518 paper's title :  Comparison Against Task Driven Artificial Neural Networks Reveals Functional Properties in Mouse Visual Cortex
# NO.519 paper's title :  Mixtape: Breaking the Softmax Bottleneck Efficiently
# NO.520 paper's title :  Variance Reduced Policy Evaluation with Smooth Function Approximation
# NO.521 paper's title :  Learning GANs and Ensembles Using Discrepancy
# NO.522 paper's title :  Co-Generation with GANs using AIS based HMC
# NO.523 paper's title :  AttentionXML: Label Tree-based Attention-Aware Deep Model for High-Performance Extreme Multi-Label Text Classification
# NO.524 paper's title :  Addressing Sample Complexity in Visual Tasks Using HER and Hallucinatory GANs
# NO.525 paper's title :  Abstract Reasoning with Distracting Features
# NO.526 paper's title :  Generalized Block-Diagonal Structure Pursuit: Learning Soft Latent Task Assignment against Negative Transfer
# NO.527 paper's title :  Adversarial Training and Robustness for Multiple Perturbations
# NO.528 paper's title :  Doubly-Robust Lasso Bandit
# NO.529 paper's title :  DM2C: Deep Mixed-Modal Clustering
# NO.530 paper's title :  MaCow: Masked Convolutional Generative Flow
# NO.531 paper's title :  Learning by Abstraction: The Neural State Machine for Visual Reasoning
# NO.532 paper's title :  Adaptive Gradient-Based Meta-Learning Methods
# NO.533 paper's title :  Equipping Experts/Bandits with Long-term Memory
# NO.534 paper's title :  A Regularized Approach to Sparse Optimal Policy in Reinforcement Learning
# NO.535 paper's title :  Scalable inference of topic evolution via models for latent geometric structures
# NO.536 paper's title :  Effective End-to-end Unsupervised Outlier Detection via Inlier Priority of Discriminative Network
# NO.537 paper's title :  Deep Active Learning with a Neural Architecture Search
# NO.538 paper's title :  Efficiently escaping saddle points on manifolds
# NO.539 paper's title :  AutoAssist: A Framework to Accelerate Training of Deep Neural Networks
# NO.540 paper's title :  DFNets: Spectral CNNs for Graphs with Feedback-looped Filters
# NO.541 paper's title :  Learning Dynamics of Attention: Human Prior for Interpretable Machine Reasoning
# NO.542 paper's title :  Comparing Unsupervised Word Translation Methods Step by Step
# NO.543 paper's title :  Learning from Crap Data via Generation
# NO.544 paper's title :  Constrained deep neural network architecture search for IoT devices accounting hardware calibration
# ...
# NO.1256 paper's title :  Defending Neural Backdoors via Generative Distribution Modeling
# NO.1257 paper's title :  Are Sixteen Heads Really Better than One?
# NO.1258 paper's title :  Multi-resolution Multi-task Gaussian Processes
# NO.1259 paper's title :  Variational Bayesian Optimal Experimental Design
# NO.1260 paper's title :  Universal Approximation of Input-Output Maps by Temporal Convolutional Nets
# NO.1261 paper's title :  Provable Certificates for Adversarial Examples: Fitting a Ball in the Union of Polytopes
# NO.1262 paper's title :  Reinforcement Learning with Convex Constraints
# NO.1263 paper's title :  User-Specified Local Differential Privacy in Unconstrained Adaptive Online Learning
# NO.1264 paper's title :  Stochastic Bandits with Context Distributions
# NO.1265 paper's title :  Inducing brain-relevant bias in natural language processing models
# NO.1266 paper's title :  Using a Logarithmic Mapping to Enable Lower Discount Factors in Reinforcement Learning
# NO.1267 paper's title :  Recovering Bandits
# NO.1268 paper's title :  Computing Linear Restrictions of Neural Networks
# NO.1269 paper's title :  Learning Positive Functions with Pseudo Mirror Descent
# NO.1270 paper's title :  Correlation Priors for Reinforcement Learning
# NO.1271 paper's title :  Fast, Provably convergent IRLS Algorithm for p-norm Linear Regression
# NO.1272 paper's title :  A Similarity-preserving Network Trained on Transformed Images Recapitulates Salient Features of the Fly Motion Detection Circuit
# NO.1273 paper's title :  Differentially Private Covariance Estimation
# NO.1274 paper's title :  Outlier Detection and Robust PCA Using a Convex Measure of Innovation
# NO.1275 paper's title :  Integrating mechanistic and structural causal models enables counterfactual inference in complex systems
# NO.1276 paper's title :  Are Disentangled Representations Helpful for Abstract Visual Reasoning?
# NO.1277 paper's title :  PowerSGD: Practical Low-Rank Gradient Compression for Distributed Optimization
# NO.1278 paper's title :  Stochastic Frank-Wolfe for Composite Convex Minimization
# NO.1279 paper's title :  Consistent Constraint-Based Causal Structure Learning
# NO.1280 paper's title :  Unsupervised Discovery of Temporal Structure in Noisy Data with Dynamical Components Analysis
# NO.1281 paper's title :  Sample Efficient Active Learning of Causal Trees
# NO.1282 paper's title :  Efficient Neural Architecture Transformation Search in Channel-Level for Object Detection
# NO.1283 paper's title :  Robust Attribution Regularization
# NO.1284 paper's title :  Computational Mirrors: Blind Inverse Light Transport by Deep Matrix Factorization
# NO.1285 paper's title :  When to use parametric models in reinforcement learning?
# NO.1286 paper's title :  General E(2)-Equivariant Steerable CNNs
# NO.1287 paper's title :  Characterization and Learning of Causal Graphs with Latent Variables from Soft Interventions
# NO.1288 paper's title :  Structure Learning with Side Information: Sample Complexity
# NO.1289 paper's title :  Untangling in Invariant Speech Recognition
# NO.1290 paper's title :  Flexible information routing in neural populations through stochastic comodulation
# NO.1291 paper's title :  Generalization Bounds in the Predict-then-Optimize Framework
# NO.1292 paper's title :  Categorized Bandits
# NO.1293 paper's title :  Worst-Case Regret Bounds for Exploration via Randomized Value Functions
# NO.1294 paper's title :  Efficient characterization of electrically evoked responses for neural interfaces
# NO.1295 paper's title :  Differentially Private Distributed Data Summarization under Covariate Shift
# NO.1296 paper's title :  Hamiltonian descent for composite objectives
# NO.1297 paper's title :  Implicit Regularization of Accelerated Methods in Hilbert Spaces
# NO.1298 paper's title :  Non-Asymptotic Pure Exploration by Solving Games
# NO.1299 paper's title :  Implicit Posterior Variational Inference for Deep Gaussian Processes
# NO.1300 paper's title :  Deep Multi-State Dynamic Recurrent Neural Networks Operating on Wavelet Based Neural Features for Robust Brain Machine Interfaces
# NO.1301 paper's title :  Censored Semi-Bandits: A Framework for Resource Allocation with Censored Feedback
# NO.1302 paper's title :  Cormorant: Covariant Molecular Neural Networks
# NO.1303 paper's title :  Reverse KL-Divergence Training of Prior Networks: Improved Uncertainty and Adversarial Robustness
# NO.1304 paper's title :  Reflection Separation using a Pair of Unpolarized and Polarized Images
# NO.1305 paper's title :  Policy Poisoning in Batch Reinforcement Learning and Control
# NO.1306 paper's title :  Low-Complexity Nonparametric Bayesian Online Prediction with Universal Guarantees
# NO.1307 paper's title :  Pure Exploration with Multiple Correct Answers
# NO.1308 paper's title :  Explaining Landscape Connectivity of Low-cost Solutions for Multilayer Nets
# NO.1309 paper's title :  On the Benefits of Disentangled Representations
# NO.1310 paper's title :  Compiler Auto-Vectorization using Imitation Learning
# NO.1311 paper's title :  A Generalized Algorithm for Multi-Objective RL and Policy Adaptation
# NO.1312 paper's title :  Exact Gaussian Processes on a Million Data Points
# NO.1313 paper's title :  Bayesian Layers: A Module for Neural Network Uncertainty
# NO.1314 paper's title :  Learning Compositional Neural Programs with Recursive Tree Search and Planning
# NO.1315 paper's title :  Nonparametric Contextual Bandits in Metric Spaces with Unknown Metric
# NO.1316 paper's title :  Qsparse-local-SGD: Distributed SGD with Quantization, Sparsification and Local Computations
# NO.1317 paper's title :  Likelihood Ratios for Out-of-Distribution Detection
# NO.1318 paper's title :  Discrete Flows: Invertible Generative Models of Discrete Data
# NO.1319 paper's title :  Mindreader: A Self Validation Network for Object-Level Human Attention Reasoning
# NO.1320 paper's title :  Model Selection for Contextual Bandits
# NO.1321 paper's title :  Sliced Gromov-Wasserstein
# NO.1322 paper's title :  Towards Practical Alternating Least-Squares for CCA
# NO.1323 paper's title :  Deep Leakage from Gradients
# NO.1324 paper's title :  Invariance-inducing regularization using worst-case transformations suffices to boost accuracy and spatial robustness
# NO.1325 paper's title :  Algorithm-Dependent Generalization Bounds for Overparameterized Deep Residual Networks
# NO.1326 paper's title :  Value Function in Frequency Domain and Characteristic Value Iteration
# NO.1327 paper's title :  Icebreaker: Efficient Information Acquisition with Active Learning
# NO.1328 paper's title :  Algorithmic Guarantees for Inverse Imaging with Untrained Network Priors
# NO.1329 paper's title :  Planning with Goal-Conditioned Policies
# NO.1330 paper's title :  Don't take it lightly: Phasing optical random projections with unknown operators
# NO.1331 paper's title :  Generating Diverse High-Fidelity Images with VQVAE-2
# NO.1332 paper's title :  Generalized Matrix Means for Semi-Supervised Learning with Multilayer Graphs
# NO.1333 paper's title :  Online Optimal Control with Linear Dynamics and Predictions: Algorithms and Regret Analysis
# NO.1334 paper's title :  Missing Not at Random in Matrix Completion: The Effectiveness of Estimating Missingness Probabilities Under a Low Nuclear Norm Assumption
# NO.1335 paper's title :  MelGAN: Generative Adversarial Networks for Conditional Waveform Synthesis
# NO.1336 paper's title :  Offline Contextual Bandits with High Probability Fairness Guarantees
# NO.1337 paper's title :  Solving a Class of Non-Convex Min-Max Games Using Iterative First Order Methods
# NO.1338 paper's title :  Semantic-Guided Multi-Attention Localization for Zero-Shot Learning
# NO.1339 paper's title :  Interpreting and improving natural-language processing (in machines) with  natural language-processing (in the brain)
# NO.1340 paper's title :  Function-Space Distributions over Kernels
# NO.1341 paper's title :  SGD for Least Squares Regression: Towards Minimax Optimality with the Final Iterate
# NO.1342 paper's title :  Compositional Plan Vectors
# NO.1343 paper's title :  Locally Private Learning without Interaction Requires Separation
# NO.1344 paper's title :  Robust Bi-Tempered Logistic Loss Based on Bregman Divergences
# NO.1345 paper's title :  Computational Separations between Sampling and Optimization
# NO.1346 paper's title :  Surfing: Iterative Optimization Over Incrementally Trained Deep Networks
# NO.1347 paper's title :  Population-based Meta-Optimizer Guided by Posterior Estimation
# NO.1348 paper's title :  On Human-Aligned Risk Minimization
# NO.1349 paper's title :  Semi-Parametric Efficient Policy Learning with Continuous Actions
# NO.1350 paper's title :  Multi-task Learning for Aggregated Data using Gaussian Processes
# NO.1351 paper's title :  Minimal Variance Sampling in Stochastic Gradient Boosting
# NO.1352 paper's title :  Precise and Scalable Convex Relaxations for Robustness Certification
# NO.1353 paper's title :  An Algorithm to Learn Polytree Networks with Hidden Nodes
# NO.1354 paper's title :  Efficiently Learning Fourier Sparse Set Functions
# NO.1355 paper's title :  Projected Stein Variational Newton: A Fast and Scalable Bayesian Inference Method in High Dimensions
# NO.1356 paper's title :  Invariance and identifiability issues for word embeddings
# NO.1357 paper's title :  Generalization Error Analysis of Quantized Compressive Learning
# NO.1358 paper's title :  Multi-Criteria Dimensionality Reduction with Applications to Fairness
# NO.1359 paper's title :  Efficient Rematerialization for Deep Networks
# NO.1360 paper's title :  Fast Agent Resetting in Training
# NO.1361 paper's title :  Heterogeneous Treatment Effects with Instruments
# NO.1362 paper's title :  Understanding Sparse JL for Feature Hashing
# NO.1363 paper's title :  Constraint Augmented Reinforcement Learning for Text-based Recommendation and Generation
# NO.1364 paper's title :  Flexible Modeling of Diversity with Strongly Log-Concave Distributions
# NO.1365 paper's title :  Momentum-Based Variance Reduction in Non-Convex SGD
# NO.1366 paper's title :  Search on the Replay Buffer: Bridging Planning and Reinforcement Learning
# NO.1367 paper's title :  Can Unconditional Language Models Recover Arbitrary Sentences?
# NO.1368 paper's title :  Group Retention when Using Machine Learning in Sequential Decision Making: the Interplay between User Dynamics and Fairness
# NO.1369 paper's title :  Faster width-dependent algorithm for mixed packing and covering LPs
# NO.1370 paper's title :  Flattening a Hierarchical Clustering through Active Learning
# NO.1371 paper's title :  DeepWave: A Recurrent Neural-Network for Real-Time Acoustic Imaging
# NO.1372 paper's title :  Certifying Geometric Robustness of Neural Networks
# NO.1373 paper's title :  Goal-conditioned Imitation Learning
# NO.1374 paper's title :  Robust exploration in linear quadratic reinforcement learning
# NO.1375 paper's title :  DRUM: End-To-End Differentiable Rule Mining On Knowledge Graphs
# NO.1376 paper's title :  Kernel Truncated Randomized Ridge Regression: Optimal Rates and Low Noise Acceleration
# NO.1377 paper's title :  Input-Output Equivalence of Unitary and Contractive RNNs
# NO.1378 paper's title :  Hamiltonian Neural Networks
# NO.1379 paper's title :  Preventing Gradient Attenuation in Lipschitz Constrained Convolutional Networks
# NO.1380 paper's title :  Deep and Structured Similarity Matching via Deep and Structured Hebbian/Anti-Hebbian Networks
# NO.1381 paper's title :  Understanding the Representation Power of Graph Neural Networks in Learning Graph Topology
# NO.1382 paper's title :  Multiple Futures Prediction
# NO.1383 paper's title :  Explicitly disentangling image content from translation and rotation with spatial-VAE
# NO.1384 paper's title :  A Perspective on False Discovery Rate Control via Knockoffs
# NO.1385 paper's title :  A Kernel Loss for Solving the Bellman Equation
# NO.1386 paper's title :  Low-Rank Bandit Methods for High-Dimensional Dynamic Pricing
# NO.1387 paper's title :  Differential Privacy Has Disparate Impact on Model Accuracy
# NO.1388 paper's title :  Riemannian batch normalization for SPD neural networks
# NO.1389 paper's title :  Neural Taskonomy: Inferring the Similarity of Task-Derived Representations from Brain Activity
# NO.1390 paper's title :  Stacked Capsule Autoencoders
# NO.1391 paper's title :  Learning Reward Machines for Partially Observable Reinforcement Learning
# NO.1392 paper's title :  Learning Representations by Maximizing Mutual Information Across Views
# NO.1393 paper's title :  Learning Deep MRFs with Amortized Bethe Free Energy Minimization
# NO.1394 paper's title :  Small ReLU networks are powerful memorizers: a tight analysis of memorization capacity
# NO.1395 paper's title :  Legendre Memory Units: Continuous-Time Representation in Recurrent Neural Networks
# NO.1396 paper's title :  Exact Combinatorial Optimization with Graph Convolutional Neural Networks
# NO.1397 paper's title :  Fast structure learning with modular regularization
# NO.1398 paper's title :  Wasserstein Dependency Measure for Representation Learning
# NO.1399 paper's title :  TAB-VCR: Tags and Attributes for Visual Commonsense Reasoning
# NO.1400 paper's title :  Universality and individuality in neural dynamics across large populations of recurrent networks
# NO.1401 paper's title :  End-to-End Learning on 3D Protein Structure for Interface Prediction
# NO.1402 paper's title :  A Family of Robust Stochastic Operators for Reinforcement Learning
# NO.1403 paper's title :  Improving Model Robustness and Uncertainty Estimates with Self-Supervised Learning
# NO.1404 paper's title :  Inherent Tradeoffs in Learning Fair Representation
# NO.1405 paper's title :  Are deep ResNets provably better than linear predictors?
# NO.1406 paper's title :  Reverse engineering recurrent networks for sentiment classification reveals line attractor dynamics
# NO.1407 paper's title :  BehaveNet: nonlinear embedding and Bayesian neural decoding of behavioral videos
# NO.1408 paper's title :  Variational Mixture-of-Experts Autoencoders for Multi-Modal Deep Generative Models
# NO.1409 paper's title :  Gradient-based Adaptive Markov Chain Monte Carlo
# NO.1410 paper's title :  On the Role of Inductive Bias From Simulation and the Transfer to the Real World: a new Disentanglement Dataset
# NO.1411 paper's title :  Imitation-Projected Policy Gradient for Programmatic Reinforcement Learning
# NO.1412 paper's title :  Learning Data Manipulation for Augmentation and Weighting
# NO.1413 paper's title :  Exploring Algorithmic Fairness in Robust Graph Covering Problems
# NO.1414 paper's title :  Abstraction based Output Range Analysis for Neural Networks
# NO.1415 paper's title :  Space and Time Efficient Kernel Density Estimation in High Dimensions
# NO.1416 paper's title :  PIDForest: Anomaly Detection and Certification via Partial Identification
# NO.1417 paper's title :  Generative Models for Graph-Based Protein Design
# NO.1418 paper's title :  The Geometry of Deep Networks: Power Diagram Subdivision
# NO.1419 paper's title :  Approximate Feature Collisions in Neural Nets
# NO.1420 paper's title :  Ease-of-Teaching and Language Structure from Emergent Communication
# NO.1421 paper's title :  Generalization in multitask deep neural classifiers: a statistical physics approach
# NO.1422 paper's title :  Distributionally Optimistic Optimization Approach to Nonparametric Likelihood Approximation
# NO.1423 paper's title :  On Relating Explanations and Adversarial Examples
# NO.1424 paper's title :  On the equivalence between graph isomorphism testing and function approximation with GNNs
# NO.1425 paper's title :  Surround Modulation: A Bio-inspired Connectivity Structure for Convolutional Neural Networks
# NO.1426 paper's title :  Self-attention with Functional Time Representation Learning
# NO.1427 paper's title :  Re-randomized Densification for One Permutation Hashing and Bin-wise Consistent Weighted Sampling
# NO.1428 paper's title :  Enabling hyperparameter optimization in sequential autoencoders for spiking neural data

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
from collections import Counter

print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /home/xyang2/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords_deep_learning = ['learning', 'network', 'neural', 'networks', 'deep', 'via', 'using', 'convolutional',
                           'single', 'data', 'method', 'based', 'beyond', 'model', 'algorithm', 'models', 'methods', 'evaluation', 'task', 'tasks', 'fast']

keyword_list = []
for i, title in enumerate(data_set):
    word_list = title.split(" ")
    word_list = list(set(word_list))

    word_list_cleaned = [] 
    for word in word_list: 
        if not word.strip():
            continue
        word = word.lower()
        if word not in stopwords.words('english') and word not in stopwords_deep_learning: #remove stopwords
            word_list_cleaned.append(word)

    for k in range(len(word_list_cleaned)):
        keyword_list.append(word_list_cleaned[k])
        
keyword_counter = Counter(keyword_list)

print('{} different keywords before merging'.format(len(keyword_counter)))

# Merge duplicates: CNNs and CNN
duplicates = []
for k in keyword_counter:
    if k+'s' in keyword_counter:
        duplicates.append(k)
for k in duplicates:
    keyword_counter[k] += keyword_counter[k+'s']
    del keyword_counter[k+'s']
print('{} different keywords after merging'.format(len(keyword_counter)))
print(keyword_counter)  

print("")
# Out:
# 2905 different keywords before merging
# 2714 different keywords after merging
# Counter({'graph': 69, 'optimization': 69, 'reinforcement': 60, 'adversarial': 53, 'representation': 53, 'efficient': 47, 'gradient': 46, 'stochastic': 45, 'optimal': 44, 'generative': 43, 'adaptive': 38, 'training': 37, 'bayesian': 37, 'bandit': 36, 'robust': 35, 'image': 35, 'estimation': 34, 'variational': 34, 'linear': 33, 'dynamic': 33, 'online': 33, 'analysis': 30, 'inference': 30, 'prediction': 29, 'regression': 29, 'time': 28, 'sparse': 28, 'function': 28, 'bound': 28, 'algorithms': 26, 'point': 26, 'framework': 25, 'generalization': 25, 'sampling': 25, 'processes': 25, 'detection': 24, 'robustness': 24, 'modeling': 24, 'kernel': 23, 'unsupervised': 22, 'structure': 22, 'policy': 22, 'search': 22, 'approach': 22, 'sample': 22, 'classification': 21, 'approximation': 21, 'toward': 20, 'distribution': 20, 'convergence': 20, 'recurrent': 20, 'embedding': 19, 'object': 19, 'visual': 19, 'private': 19, 'control': 19, 'regret': 19, 'generation': 19, 'latent': 19, 'variance': 18, 'random': 18, 'clustering': 18, 'distributed': 18, 'machine': 18, 'regularization': 17, 'descent': 17, 'gaussian': 17, 'rate': 17, 'feature': 17, 'causal': 17, 'game': 17, 'conditional': 16, 'continuous': 16, 'scalable': 16, 'gan': 15, 'segmentation': 15, 'semantic': 15, 'problem': 15, 'hierarchical': 15, 'transfer': 15, 'local': 15, 'markov': 15, 'architecture': 15, 'understanding': 15, 'uncertainty': 15, 'complexity': 15, 'structured': 15, 'space': 15, 'language': 15, 'high-dimensional': 14, 'transport': 14, 'loss': 14, 'approximate': 14, 'exploration': 14, 'information': 14, 'sgd': 14, 'convex': 14, 'inverse': 13, 'noise': 13, 'flow': 13, '3d': 13, 'decision': 13, 'prior': 13, 'reduction': 13, 'differential': 13, 'reasoning': 13, 'reward': 13, 'large': 12, 'implicit': 12, 'generalized': 12, 'temporal': 12, 'bias': 12, 'active': 12, 'constraint': 12, 'low': 12, 'video': 11, 'differentially': 11, 'guarantees': 11, 'privacy': 11, 'state': 11, 'metric': 11, 'low-rank': 11, 'semi-supervised': 11, 'multi-agent': 11, 'autoencoder': 11, 'global': 11, 'contextual': 11, 'sequence': 11, 'matrix': 11, 'memory': 11, 'selection': 10, 'new': 10, 'mean': 10, 'quadratic': 10, 'minimization': 10, 'accurate': 10, 'feedback': 10, 'set': 10, 'matching': 10, 'fairness': 10, 'variable': 10, 'exact': 10, 'system': 10, 'attention': 9, 'sequential': 9, 'distance': 9, 'wasserstein': 9, 'perspective': 9, 'self-supervised': 9, 'continual': 9, 'domain': 9, 'synthesis': 9, 'application': 9, 'error': 9, 'human': 9, 'recognition': 9, 'noisy': 9, 'batch': 9, 'empirical': 9, 'label': 9, 'statistical': 9, 'classifier': 9, 'unified': 9, 'communication': 9, 'planning': 9, 'probabilistic': 9, 'improved': 9, 'provably': 9, 'functional': 9, 'series': 9, 'net': 9, 'meta-learning': 8, 'monte': 8, 'relu': 8, 'learn': 8, 'solving': 8, 'subspace': 8, 'proximal': 8, 'theory': 8, 'differentiable': 8, 'dataset': 8, 'natural': 8, 'tree': 8, 'off-policy': 8, 'improving': 8, 'order': 8, 'testing': 8, 'multiple': 8, 'regularized': 8, 'non-convex': 8, 'identification': 8, 'step': 8, 'tight': 8, 'discovery': 8, 'effect': 8, 'forecasting': 7, 'networks:': 7, 'carlo': 7, 'reconstruction': 7, 'multi-armed': 7, 'importance': 7, 'process': 7, 'manifold': 7, 'convolution': 7, 'knowledge': 7, 'accelerated': 7, 'without': 7, 'combinatorial': 7, 'cost': 7, 'ranking': 7, 'value': 7, 'risk': 7, 'meta': 7, 'similarity': 7, 'normalization': 7, 'text': 7, 'disentangled': 7, 'code': 7, 'discrete': 7, 'consistent': 7, 'practical': 7, 'lower': 7, 'component': 7, 'projection': 7, 'factorization': 7, 'layer': 7, 'correlation': 7, 'constrained': 7, 'explanations': 7, 'brain': 7, 'attack': 7, 'zero-shot': 6, 'imitation': 6, 'block': 6, 'node': 6, 'weighted': 6, 'interpretable': 6, 'tensor': 6, 'transformer': 6, 'sketching': 6, 'scene': 6, 'correlated': 6, 'better': 6, 'polynomial': 6, 'compression': 6, 'auxiliary': 6, 'power': 6, 'saddle': 6, 'multivariate': 6, 'universal': 6, 'aggregation': 6, 'estimating': 6, 'confidence' ...

# %%
# Show N most common keywords and their frequencies
num_keyowrd = 120
keywords_counter_vis = keyword_counter.most_common(num_keyowrd)

plt.rcdefaults()
fig, ax = plt.subplots(figsize=(8, 20))

key = [k[0] for k in keywords_counter_vis] 
value = [k[1] for k in keywords_counter_vis] 
y_pos = np.arange(len(key))
ax.barh(y_pos, value, align='center', color='green', ecolor='black', log=True)
ax.set_yticks(y_pos)
ax.set_yticklabels(key, rotation=0, fontsize=8)
ax.invert_yaxis() 
for i, v in enumerate(value):
    ax.text(v + 3, i + .25, str(v), color='black', fontsize=8)
# ax.text(y_pos, value, str(value))
ax.set_xlabel('Frequency')
ax.set_title('NeurIPS 2019 Submission Top {} Keywords'.format(num_keyowrd))

plt.show()

# %%
# Show the word cloud forming by keywords
from wordcloud import WordCloud
NIPS = WordCloud(max_font_size=800, max_words=160, 
                      width=1280, height=640,
                      background_color="black").generate(' '.join(['NeuIPS'] * 500))

wordcloud = WordCloud(max_font_size=64, max_words=160, 
                      width=1280, height=640,
                      background_color="black").generate(' '.join(keyword_list))
plt.figure(figsize=(16, 8))
plt.imshow(NIPS, interpolation="bilinear", alpha=1)
plt.imshow(wordcloud, interpolation="bilinear", alpha=.5)
plt.axis("off")
plt.show()

# %%
import matplotlib
